# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-Week8/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (No imports are needed for this program)

# FUNCTION DEFINITIONS
# Define a function named is_palindrome
# The function should accept one parameter (the word to check)
# Convert the word to lowercase so the check is case-insensitive
# Reverse the word using string slicing
# Compare the original word to the reversed word
# Return True if they are the same, otherwise return False

# PROGRAM LOGIC
# Prompt the user to enter a word
# Call the is_palindrome function using the user's input
# Store the returned True or False value
# Use an if/else statement to print a friendly message
# Tell the user whether the word is a palindrome or not
