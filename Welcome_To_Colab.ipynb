# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-Week8/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (No imports needed)

# FUNCTION DEFINITIONS
def is_palindrome(word):
    # Convert the word to lowercase
    word = word.lower()

    # Reverse the word using slicing
    reversed_word = word[::-1]

    # Compare the word to its reverse
    return word == reversed_word

# PROGRAM LOGIC
# Ask the user to enter a word
user_word = input("Enter a word to check if it is a palindrome: ")

# Call the function and store the result
result = is_palindrome(user_word)

# Display the result to the user
if result:
    print(f'"{user_word}" is a palindrome!')
else:
    print(f'"{user_word}" is NOT a palindrome.')
# Out:
# Enter a word to check if it is a palindrome: Racecar
# "Racecar" is a palindrome!
